# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('seaborn-v0_8')

# %%
df = pd.read_csv((r'../data/Salary_Data.csv'))
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.shape
# Out:
# (6704, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6704 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6702 non-null   float64
#  1   Gender               6702 non-null   object
#  2   Education Level      6701 non-null   object
#  3   Job Title            6702 non-null   object
#  4   Years of Experience  6701 non-null   float64
#  5   Salary               6699 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 314.4+ KB

# %%
df['Age'] = df['Age'].astype('Int64')
df['Salary'] = df['Salary'].astype('Int64')

# %%
df.sample(5)
# Out:
#       Age  Gender    Education Level                  Job Title  \
# 1036   33  Female           Master's            Product Manager
# 142    33    Male         Bachelor's  Junior Software Developer
# 4627   23  Female  Bachelor's Degree      Junior HR Coordinator
# 4573   27  Female    Master's Degree       Junior HR Generalist
# 5686   32    Male  Bachelor's Degree            Product Manager
#
#       Years of Experience  Salary
# 1036                 11.0  195000
# 142                   5.0   50000
# 4627                  1.0   32000
# 4573                  2.0   42000
# 5686                  7.0  120000

# %% [markdown]
# Análises Univariadas

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(14,5))

sns.histplot(data=df, x='Age', bins=10,ax=ax1,legend=False,kde=True)
ax1.set_title('Histograma Idades')
ax1.set_xlabel('Idade')
ax1.set_ylabel('Quantidade')

sns.histplot(data=df, x='Years of Experience', bins=10,ax=ax2,legend=False,kde=True)
ax2.set_title('Histograma Anos Experiência')
ax2.set_xlabel('Tempo')
ax2.set_ylabel('Quantidade')

sns.histplot(data=df, x='Salary', bins=10,ax=ax3,legend=False,kde=True)
ax3.set_title('Histograma Salários')
ax3.set_xlabel('Salário')
ax3.set_ylabel('Quantidade')

plt.tight_layout()
plt.show()

# %%
df.sample(5)
# Out:
#       Age  Gender    Education Level                  Job Title  \
# 687    34  Female           Master's            Product Manager
# 6078   32  Female                PhD             Data Scientist
# 979    27    Male         Bachelor's          Software Engineer
# 5597   26    Male  Bachelor's Degree           Product Designer
# 133    47    Male                PhD  Senior Research Scientist
#
#       Years of Experience  Salary
# 687                  11.0  196000
# 6078                  9.0  145000
# 979                   4.0  160000
# 5597                  2.0   50000
# 133                  22.0  160000

# %%
# 10 Maiores médias de salários

top_media_salarios = df.groupby('Job Title')['Salary'].mean().sort_values(ascending=False).head(10).reset_index()


plt.figure(figsize=(6,4))
sns.barplot(data=top_media_salarios,x='Salary',y='Job Title',hue='Job Title',palette='mako')
plt.title('10 maiores médias de salários')
plt.show()

# %%
# Scatterplot relacionando os anos de experiencia com o salário

plt.figure(figsize=(6,4))
sns.scatterplot(data=df,x='Salary',y='Age',alpha=0.3)
plt.title('Relação Exp x Salário')
plt.show()

# %%
sns.scatterplot(data=df, x='Salary', y='Age', alpha=0.3)
# Out:
# <Axes: xlabel='Salary', ylabel='Age'>

# %%
plt.figure(figsize=(8, 6))
# Usa histplot com x e y para criar um mapa de calor 2D
sns.histplot(data=df, x='Salary', y='Age', bins=50, cmap="viridis", cbar=True)

plt.title('Relação Idade x Salário (Densidade 2D)')
plt.xlabel('Salário')
plt.ylabel('Idade')
plt.show()
