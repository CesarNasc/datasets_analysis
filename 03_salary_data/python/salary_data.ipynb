# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('seaborn-v0_8')

# %%
df = pd.read_csv((r'../data/Salary_Data.csv'))
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.shape
# Out:
# (6704, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6704 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6702 non-null   float64
#  1   Gender               6702 non-null   object
#  2   Education Level      6701 non-null   object
#  3   Job Title            6702 non-null   object
#  4   Years of Experience  6701 non-null   float64
#  5   Salary               6699 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 314.4+ KB

# %%
df['Age'] = df['Age'].astype('Int64')
df['Salary'] = df['Salary'].astype('Int64')

# %%
df.sample(5)
# Out:
#       Age  Gender    Education Level                       Job Title  \
# 5887   29  Female  Bachelor's Degree                 Product Manager
# 3403   45    Male                PhD  Senior Human Resources Manager
# 5787   30  Female  Bachelor's Degree           Marketing Coordinator
# 2267   26    Male  Bachelor's Degree              Software Developer
# 3763   26    Male  Bachelor's Degree              Software Developer
#
#       Years of Experience  Salary
# 5887                  5.0   80000
# 3403                 12.0  120000
# 5787                  5.0   90000
# 2267                  2.0   60000
# 3763                  3.0   60000

# %% [markdown]
# Estatísticas Univariadas

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(14,5))

sns.histplot(data=df, x='Age', bins=10,ax=ax1,legend=False,kde=True)
ax1.set_title('Histograma Idades')
ax1.set_xlabel('Idade')
ax1.set_ylabel('Quantidade')

sns.histplot(data=df, x='Years of Experience', bins=10,ax=ax2,legend=False,kde=True)
ax2.set_title('Histograma Anos Experiência')
ax2.set_xlabel('Tempo')
ax2.set_ylabel('Quantidade')

sns.histplot(data=df, x='Salary', bins=10,ax=ax3,legend=False,kde=True)
ax3.set_title('Histograma Salários')
ax3.set_xlabel('Salário')
ax3.set_ylabel('Quantidade')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(data=df, x='Age', bins=10)
plt.title('Histograma Idades')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(data=df, x='Age', bins=10)
plt.title('Histograma Idades')
plt.show()
